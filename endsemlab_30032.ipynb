# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

df=pd.DataFrame({"Area":[1200,2500,1800,900,3200],
"Rooms":[2,4,3,1,5],
"Age":[5,12,2,20,1],
"Price":[45,95,70,30,140]})

x=StandardScaler().fit_transform(df)
p=PCA(2)
y=p.fit_transform(x)

print(y)
print(p.explained_variance_ratio_)

plt.scatter(y[:,0],y[:,1]); plt.show()
plt.plot(PCA().fit(x).explained_variance_ratio_); plt.show()
# Out:
# [[-1.09511378 -0.91788262]
#  [ 0.78893022  0.9305571 ]
#  [ 0.16566598 -0.84880771]
#  [-2.6768859   0.71973578]
#  [ 2.81740349  0.11639745]]
# [0.84763054 0.14802438]
